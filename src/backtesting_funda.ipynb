# %%
import yfinance as yf

import pandas as pd
import numpy as np
import os

from skfolio import Population, RiskMeasure, Portfolio
from skfolio.preprocessing import prices_to_returns
from skfolio.optimization import (
    MeanRisk,
    ObjectiveFunction,
    EqualWeighted,
    InverseVolatility,
    RiskBudgeting
)

import dotenv 
dotenv.load_dotenv()
# Out:
# True

# %%
DATA_PATH = os.getenv('DATA_PATH')

def get_path(filename):
    return os.path.join(DATA_PATH, 'financials',filename)

get_path('backtest.csv')
# Out:
# './res/data/financials/backtest.csv'

# %%
df = pd.read_csv(get_path('backtest1.csv'))
df
# Out:
#           date      symbol marketcapname              sector
# 0   01-01-2015       GLAXO      Largecap     Pharmaceuticals
# 1   01-01-2016       GLAXO      Largecap     Pharmaceuticals
# 2   01-01-2016  VINATIORGA        Midcap         Industrials
# 3   01-01-2016  AJANTPHARM      Largecap     Pharmaceuticals
# 4   01-01-2016       SUNTV      Largecap               Media
# 5   01-01-2016   ZFCVINDIA      Largecap                Auto
# 6   02-01-2017   KANSAINER      Largecap         Industrials
# 7   02-01-2017  AJANTPHARM      Largecap     Pharmaceuticals
# 8   02-01-2017      AIAENG      Largecap         Industrials
# 9   02-01-2017       SUNTV      Largecap               Media
# 10  02-01-2017      VGUARD      Largecap                FMCG
# 11  01-01-2018   FINCABLES      Largecap         Industrials
# 12  01-01-2018   KANSAINER      Largecap         Industrials
# 13  01-01-2018     3MINDIA      Largecap       Miscellaneous
# 14  01-01-2018  VINATIORGA        Midcap         Industrials
# 15  01-01-2018       SUNTV      Largecap               Media
# 16  01-01-2018      VGUARD      Largecap                FMCG
# 17  01-01-2018   ZFCVINDIA      Largecap                Auto
# 18  01-01-2018         BLS        Midcap                 I.T
# 19  01-01-2020   BATAINDIA        Midcap                FMCG
# 20  01-01-2020    SKFINDIA      Largecap         Industrials
# 21  01-01-2020   RATNAMANI      Largecap              Metals
# 22  01-01-2020  VINATIORGA        Midcap         Industrials
# 23  01-01-2020     FINEORG        Midcap         Industrials
# 24  01-01-2020     COFORGE      Largecap                 I.T
# 25  01-01-2021  VINATIORGA        Midcap         Industrials
# 26  01-01-2021     FINEORG        Midcap         Industrials
# 27  01-01-2021  AJANTPHARM      Largecap     Pharmaceuticals
# 28  01-01-2021     COFORGE      Largecap                 I.T
# 29  01-01-2021       SUNTV      Largecap               Media
# 30  03-01-2022  JBCHEPHARM      Largecap     Pharmaceuticals
# 31  03-01-2022  AJANTPHARM      Largecap     Pharmaceuticals
# 32  03-01-2022       SUNTV      Largecap               Media
# 33  03-01-2022     KPRMILL      Largecap                FMCG
# 34  03-01-2022  PERSISTENT      Largecap                 I.T
# 35  03-01-2022       GLAND      Largecap     Pharmaceuticals
# 36  02-01-2023    SKFINDIA      Largecap         Industrials
# 37  02-01-2023  JBCHEPHARM      Largecap     Pharmaceuticals
# 38  02-01-2023  VINATIORGA        Midcap         Industrials
# 39  02-01-2023     FINEORG        Midcap         Industrials
# 40  02-01-2023    SUMICHEM      Largecap         Industrials
# 41  02-01-2023  ANANDRATHI        Midcap             Finance
# 42  01-01-2024    SKFINDIA      Largecap         Industrials
# 43  01-01-2024   DEEPAKNTR      Largecap         Industrials
# 44  01-01-2024    ASTRAZEN        Midcap     Pharmaceuticals
# 45  01-01-2024   RATNAMANI      Largecap              Metals
# 46  01-01-2024     3MINDIA      Largecap       Miscellaneous
# 47  01-01-2024   SUVENPHAR      Largecap     Pharmaceuticals
# 48  01-01-2024        CAMS      Largecap  Financial Services
# 49  01-01-2024  AJANTPHARM      Largecap     Pharmaceuticals
# 50  01-01-2024       BSOFT      Largecap                 I.T
# 51  01-01-2024      AIAENG      Largecap         Industrials
# 52  01-01-2024       SUNTV      Largecap               Media
# 53  01-01-2024       CLEAN        Midcap         Industrials
# 54  01-01-2024  ANANDRATHI        Midcap             Finance
# 55  01-01-2024         BLS        Midcap                 I.T

# %%
df['year'] = df['date'].str.split('-', expand=True)[[2]].astype(int)
df = df.drop(columns=['date'])
df
# Out:
#         symbol marketcapname              sector  year
# 0        GLAXO      Largecap     Pharmaceuticals  2015
# 1        GLAXO      Largecap     Pharmaceuticals  2016
# 2   VINATIORGA        Midcap         Industrials  2016
# 3   AJANTPHARM      Largecap     Pharmaceuticals  2016
# 4        SUNTV      Largecap               Media  2016
# 5    ZFCVINDIA      Largecap                Auto  2016
# 6    KANSAINER      Largecap         Industrials  2017
# 7   AJANTPHARM      Largecap     Pharmaceuticals  2017
# 8       AIAENG      Largecap         Industrials  2017
# 9        SUNTV      Largecap               Media  2017
# 10      VGUARD      Largecap                FMCG  2017
# 11   FINCABLES      Largecap         Industrials  2018
# 12   KANSAINER      Largecap         Industrials  2018
# 13     3MINDIA      Largecap       Miscellaneous  2018
# 14  VINATIORGA        Midcap         Industrials  2018
# 15       SUNTV      Largecap               Media  2018
# 16      VGUARD      Largecap                FMCG  2018
# 17   ZFCVINDIA      Largecap                Auto  2018
# 18         BLS        Midcap                 I.T  2018
# 19   BATAINDIA        Midcap                FMCG  2020
# 20    SKFINDIA      Largecap         Industrials  2020
# 21   RATNAMANI      Largecap              Metals  2020
# 22  VINATIORGA        Midcap         Industrials  2020
# 23     FINEORG        Midcap         Industrials  2020
# 24     COFORGE      Largecap                 I.T  2020
# 25  VINATIORGA        Midcap         Industrials  2021
# 26     FINEORG        Midcap         Industrials  2021
# 27  AJANTPHARM      Largecap     Pharmaceuticals  2021
# 28     COFORGE      Largecap                 I.T  2021
# 29       SUNTV      Largecap               Media  2021
# 30  JBCHEPHARM      Largecap     Pharmaceuticals  2022
# 31  AJANTPHARM      Largecap     Pharmaceuticals  2022
# 32       SUNTV      Largecap               Media  2022
# 33     KPRMILL      Largecap                FMCG  2022
# 34  PERSISTENT      Largecap                 I.T  2022
# 35       GLAND      Largecap     Pharmaceuticals  2022
# 36    SKFINDIA      Largecap         Industrials  2023
# 37  JBCHEPHARM      Largecap     Pharmaceuticals  2023
# 38  VINATIORGA        Midcap         Industrials  2023
# 39     FINEORG        Midcap         Industrials  2023
# 40    SUMICHEM      Largecap         Industrials  2023
# 41  ANANDRATHI        Midcap             Finance  2023
# 42    SKFINDIA      Largecap         Industrials  2024
# 43   DEEPAKNTR      Largecap         Industrials  2024
# 44    ASTRAZEN        Midcap     Pharmaceuticals  2024
# 45   RATNAMANI      Largecap              Metals  2024
# 46     3MINDIA      Largecap       Miscellaneous  2024
# 47   SUVENPHAR      Largecap     Pharmaceuticals  2024
# 48        CAMS      Largecap  Financial Services  2024
# 49  AJANTPHARM      Largecap     Pharmaceuticals  2024
# 50       BSOFT      Largecap                 I.T  2024
# 51      AIAENG      Largecap         Industrials  2024
# 52       SUNTV      Largecap               Media  2024
# 53       CLEAN        Midcap         Industrials  2024
# 54  ANANDRATHI        Midcap             Finance  2024
# 55         BLS        Midcap                 I.T  2024

# %%
def get_returns(year):
    tickers = [ t + '.NS' for t in df.loc[df.year == year].symbol.to_list()]
    start_date = f'{year}-01-01'
    end_date = f'{year+1}-01-01'
    return yf.Tickers(tickers).history(start=start_date,end=end_date)

def get_portfolio(close):
    X = prices_to_returns(close)
    model = RiskBudgeting(risk_measure=RiskMeasure.CVAR)
    return model.fit_predict(X)

# %%
returns_cache = {}

# %%
d = []

for year in range(2019, 2025):
    if year not in returns_cache:
        returns_cache[year] = get_returns(year)['Close']
    portfolio = get_portfolio(returns_cache[year])
    d.append(portfolio.returns_df)

ret = pd.DataFrame(pd.concat(d))
ret
# Out:
# [*********************100%%**********************]  0 of 0 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /nix/store/7wqlqz0m544kh1j6a2l49c7n9zwpbvpy-python3.11-yfinance-0.2.37/lib/python3.11/site-packages/yfinance/multi.py:219, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, session)
#     218 try:
# --> 219     data = _pd.concat(shared._DFS.values(), axis=1, sort=True,
#     220                       keys=shared._DFS.keys(), names=['Ticker', 'Price'])
#     221 except Exception:
#
# File /nix/store/nm9q1ykw4d8rxhyslcq50kjajy75dk2a-python3.11-pandas-2.2.1/lib/python3.11/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File /nix/store/nm9q1ykw4d8rxhyslcq50kjajy75dk2a-python3.11-pandas-2.2.1/lib/python3.11/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#
# File /nix/store/nm9q1ykw4d8rxhyslcq50kjajy75dk2a-python3.11-pandas-2.2.1/lib/python3.11/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#
# ValueError: No objects to concatenate
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 5
#       3 for year in range(2019, 2025):
#       4     if year not in returns_cache:
# ----> 5         returns_cache[year] = get_returns(year)['Close']
#       6     portfolio = get_portfolio(returns_cache[year])
#       7     d.append(portfolio.returns_df)
#
# Cell In[119], line 5, in get_returns(year)
#       3 start_date = f'{year}-01-01'
#       4 end_date = f'{year+1}-01-01'
# ----> 5 return yf.Tickers(tickers).history(start=start_date,end=end_date)
#
# File /nix/store/7wqlqz0m544kh1j6a2l49c7n9zwpbvpy-python3.11-yfinance-0.2.37/lib/python3.11/site-packages/yfinance/tickers.py:52, in Tickers.history(self, period, interval, start, end, prepost, actions, auto_adjust, repair, proxy, threads, group_by, progress, timeout, **kwargs)
#      45 def history(self, period="1mo", interval="1d",
#      46             start=None, end=None, prepost=False,
#      47             actions=True, auto_adjust=True, repair=False,
#      48             proxy=None,
#      49             threads=True, group_by='column', progress=True,
#      50             timeout=10, **kwargs):
# ---> 52     return self.download(
#      53         period, interval,
#      54         start, end, prepost,
#      55         actions, auto_adjust, repair,
#      56         proxy,
#      57         threads, group_by, progress,
#      58         timeout, **kwargs)
#
# File /nix/store/7wqlqz0m544kh1j6a2l49c7n9zwpbvpy-python3.11-yfinance-0.2.37/lib/python3.11/site-packages/yfinance/tickers.py:67, in Tickers.download(self, period, interval, start, end, prepost, actions, auto_adjust, repair, proxy, threads, group_by, progress, timeout, **kwargs)
#      60 def download(self, period="1mo", interval="1d",
#      61              start=None, end=None, prepost=False,
#      62              actions=True, auto_adjust=True, repair=False,
#      63              proxy=None,
#      64              threads=True, group_by='column', progress=True,
#      65              timeout=10, **kwargs):
# ---> 67     data = multi.download(self.symbols,
#      68                           start=start, end=end,
#      69                           actions=actions,
#      70                           auto_adjust=auto_adjust,
#      71                           repair=repair,
#      72                           period=period,
#      73                           interval=interval,
#      74                           prepost=prepost,
#      75                           proxy=proxy,
#      76                           group_by='ticker',
#      77                           threads=threads,
#      78                           progress=progress,
#      79                           timeout=timeout,
#      80                           **kwargs)
#      82     for symbol in self.symbols:
#      83         self.tickers.get(symbol, {})._history = data[symbol]
#
# File /nix/store/7wqlqz0m544kh1j6a2l49c7n9zwpbvpy-python3.11-yfinance-0.2.37/lib/python3.11/site-packages/yfinance/utils.py:103, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     100 logger.debug(f'Entering {func.__name__}()')
#     102 with IndentationContext():
# --> 103     result = func(*args, **kwargs)
#     105 logger.debug(f'Exiting {func.__name__}()')
#     106 return result
#
# File /nix/store/7wqlqz0m544kh1j6a2l49c7n9zwpbvpy-python3.11-yfinance-0.2.37/lib/python3.11/site-packages/yfinance/multi.py:223, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, session)
#     221 except Exception:
#     222     _realign_dfs()
# --> 223     data = _pd.concat(shared._DFS.values(), axis=1, sort=True,
#     224                       keys=shared._DFS.keys(), names=['Ticker', 'Price'])
#     225 data.index = _pd.to_datetime(data.index)
#     226 # switch names back to isins if applicable
#
# File /nix/store/nm9q1ykw4d8rxhyslcq50kjajy75dk2a-python3.11-pandas-2.2.1/lib/python3.11/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File /nix/store/nm9q1ykw4d8rxhyslcq50kjajy75dk2a-python3.11-pandas-2.2.1/lib/python3.11/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File /nix/store/nm9q1ykw4d8rxhyslcq50kjajy75dk2a-python3.11-pandas-2.2.1/lib/python3.11/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
from skfolio import BasePortfolio


BasePortfolio(returns=ret, observations=ret.index, compounded=True).plot_cumulative_returns()
